# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('D:/Users/arnav_mathur\Downloads\AM\Capstone/Data Science Onboarding Capstone Project Raw_Data.xlsx')

# %%
df.describe()
# Out:
#                 AIN  RollYear   TaxRateArea  totBuildingDataLines  \
# count  1.000000e+04   10000.0  10000.000000          10000.000000
# mean   4.095744e+09    2019.0    678.847400              1.076100
# std    1.582243e+09       0.0   2269.346132              0.336928
# min    2.004002e+09    2019.0      4.000000              0.000000
# 25%    2.502028e+09    2019.0     13.000000              1.000000
# 50%    4.302031e+09    2019.0     16.000000              1.000000
# 75%    5.424272e+09    2019.0     67.000000              1.000000
# max    7.563036e+09    2019.0  15938.000000              5.000000
#
#           YearBuilt  EffectiveYearBuilt       SQFTmain      Bedrooms  \
# count  10000.000000        10000.000000   10000.000000  10000.000000
# mean    1934.358500         1939.473700    2405.304400      3.848400
# std      189.166959          197.372654    7059.139913      5.665865
# min        0.000000            0.000000       0.000000      0.000000
# 25%     1930.000000         1943.000000    1208.000000      2.000000
# 50%     1952.000000         1958.000000    1596.000000      3.000000
# 75%     1968.000000         1975.000000    2278.250000      4.000000
# max     2019.000000         2019.000000  347064.000000    198.000000
#
#           Bathrooms         Units  ...    TotalValue  TotalExemption  \
# count  10000.000000  10000.000000  ...  1.000000e+04    1.000000e+04
# mean       3.015400      1.946300  ...  6.289843e+05    5.737523e+03
# std        5.669619      7.369318  ...  2.040089e+06    1.026492e+05
# min        0.000000      0.000000  ...  0.000000e+00    0.000000e+00
# 25%        2.000000      1.000000  ...  2.086160e+05    0.000000e+00
# 50%        2.000000      1.000000  ...  3.773065e+05    0.000000e+00
# 75%        3.000000      1.000000  ...  6.441738e+05    7.000000e+03
# max      198.000000    366.000000  ...  1.106204e+08    6.370382e+06
#
#        netTaxableValue  AdministrativeRegion       Cluster       HouseNo  \
# count     1.000000e+04          10000.000000  10000.000000  10000.000000
# mean      6.232468e+05              6.239300   6481.660100   6918.100400
# std       2.029801e+06              4.052836   4076.217257   6082.975637
# min       0.000000e+00              2.000000   2102.000000      0.000000
# 25%       2.044405e+05              3.000000   3127.000000   1642.000000
# 50%       3.731155e+05              4.000000   4428.000000   5227.500000
# 75%       6.403778e+05              9.000000   9184.000000  10658.500000
# max       1.106204e+08             30.000000  28405.000000  28006.000000
#
#            ZIPcode5         rowID    CENTER_LAT    CENTER_LON
# count   9999.000000  1.000000e+04  10000.000000  10000.000000
# mean   90621.415742  2.019410e+13     34.096204   -118.386369
# std      643.967297  1.582243e+09      0.123129      0.118514
# min    90001.000000  2.019200e+13     33.708126   -118.667832
# 25%    90036.000000  2.019250e+13     34.017749   -118.465366
# 50%    90077.000000  2.019430e+13     34.094632   -118.382473
# 75%    91335.000000  2.019542e+13     34.195889   -118.293634
# max    91607.000000  2.019756e+13     34.329560   -118.127673
#
# [8 rows x 32 columns]

# %%
df.shape
# Out:
# (10000, 51)

# %%
df.head()
# Out:
#       ZIPcode TaxRateArea_CITY         AIN  RollYear  TaxRateArea  \
# 0  90037-3908      LOS ANGELES  5002017003      2019          212
# 1  90008-1725      LOS ANGELES  5045009008      2019           67
# 2  91356-1624      LOS ANGELES  2157002098      2019           16
# 3  90027-4725      LOS ANGELES  5430007005      2019           13
# 4  90063-3433   unincorporated  5234006014      2019          932
#
#      AssessorID                                 PropertyLocation PropertyType  \
# 0  5002-017-003            1150 W 57TH ST  LOS ANGELES CA  90037          R-I
# 1  5045-009-008        3939 WELLINGTON RD  LOS ANGELES CA  90008          SFR
# 2  2157-002-098  18333 HATTERAS ST, NO 98  LOS ANGELES CA  91356          CND
# 3  5430-007-005          3941 CLAYTON AVE  LOS ANGELES CA  90027          SFR
# 4  5234-006-014         4250 MICHIGAN AVE  LOS ANGELES CA  90063          SFR
#
#   PropertyUseCode GeneralUseType  ... HouseFraction StreetDirection  \
# 0            0400    Residential  ...           NaN               W
# 1            0101    Residential  ...           NaN             NaN
# 2            010C    Residential  ...           NaN             NaN
# 3            0100    Residential  ...           NaN             NaN
# 4            0100    Residential  ...           NaN             NaN
#
#       StreetName  UnitNo            City  ZIPcode5           rowID  \
# 0        57TH ST     NaN  LOS ANGELES CA   90037.0  20195002017003
# 1  WELLINGTON RD     NaN  LOS ANGELES CA   90008.0  20195045009008
# 2    HATTERAS ST   NO 98  LOS ANGELES CA   91356.0  20192157002098
# 3    CLAYTON AVE     NaN  LOS ANGELES CA   90027.0  20195430007005
# 4   MICHIGAN AVE     NaN  LOS ANGELES CA   90063.0  20195234006014
#
#    CENTER_LAT  CENTER_LON                    Location 1
# 0   33.990265 -118.295401  (33.99026509, -118.29540135)
# 1   34.014630 -118.339826   (34.01462956, -118.3398262)
# 2   34.178167 -118.531645  (34.17816673, -118.53164496)
# 3   34.100852 -118.277677  (34.10085245, -118.27767676)
# 4   34.038443 -118.173973  (34.03844261, -118.17397312)
#
# [5 rows x 51 columns]

# %%
# df["ZIPcode"] = pd.to_numeric(df["ZIPcode"])

# %%
df.dtypes
# Out:
# ZIPcode                         object
# TaxRateArea_CITY                object
# AIN                              int64
# RollYear                         int64
# TaxRateArea                      int64
# AssessorID                      object
# PropertyLocation                object
# PropertyType                    object
# PropertyUseCode                 object
# GeneralUseType                  object
# SpecificUseType                 object
# SpecificUseDetail1              object
# SpecificUseDetail2              object
# totBuildingDataLines             int64
# YearBuilt                        int64
# EffectiveYearBuilt               int64
# SQFTmain                         int64
# Bedrooms                         int64
# Bathrooms                        int64
# Units                            int64
# RecordingDate                    int64
# LandValue                        int64
# LandBaseYear                     int64
# ImprovementValue                 int64
# ImpBaseYear                      int64
# TotalLandImpValue                int64
# HomeownersExemption              int64
# RealEstateExemption              int64
# FixtureValue                     int64
# FixtureExemption                 int64
# PersonalPropertyValue            int64
# PersonalPropertyExemption        int64
# isTaxableParcel?                object
# TotalValue                       int64
# TotalExemption                   int64
# netTaxableValue                  int64
# SpecialParcelClassification     object
# AdministrativeRegion             int64
# Cluster                          int64
# ParcelBoundaryDescription       object
# HouseNo                          int64
# HouseFraction                   object
# StreetDirection                 object
# StreetName                      object
# UnitNo                          object
# City                            object
# ZIPcode5                       float64
# rowID                            int64
# CENTER_LAT                     float64
# CENTER_LON                     float64
# Location 1                      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# ZIPcode                           1
# TaxRateArea_CITY                  0
# AIN                               0
# RollYear                          0
# TaxRateArea                       0
# AssessorID                        0
# PropertyLocation                  0
# PropertyType                      0
# PropertyUseCode                   0
# GeneralUseType                    0
# SpecificUseType                   0
# SpecificUseDetail1             8164
# SpecificUseDetail2             6738
# totBuildingDataLines              0
# YearBuilt                         0
# EffectiveYearBuilt                0
# SQFTmain                          0
# Bedrooms                          0
# Bathrooms                         0
# Units                             0
# RecordingDate                     0
# LandValue                         0
# LandBaseYear                      0
# ImprovementValue                  0
# ImpBaseYear                       0
# TotalLandImpValue                 0
# HomeownersExemption               0
# RealEstateExemption               0
# FixtureValue                      0
# FixtureExemption                  0
# PersonalPropertyValue             0
# PersonalPropertyExemption         0
# isTaxableParcel?                  0
# TotalValue                        0
# TotalExemption                    0
# netTaxableValue                   0
# SpecialParcelClassification    9954
# AdministrativeRegion              0
# Cluster                           0
# ParcelBoundaryDescription         0
# HouseNo                           0
# HouseFraction                  9976
# StreetDirection                7331
# StreetName                        0
# UnitNo                         8566
# City                              0
# ZIPcode5                          1
# rowID                             0
# CENTER_LAT                        0
# CENTER_LON                        0
# Location 1                        0
# dtype: int64

# %%
df.nunique()
# Out:
# ZIPcode                         9412
# TaxRateArea_CITY                   5
# AIN                            10000
# RollYear                           1
# TaxRateArea                      147
# AssessorID                     10000
# PropertyLocation                9999
# PropertyType                       5
# PropertyUseCode                   49
# GeneralUseType                     1
# SpecificUseType                    8
# SpecificUseDetail1                 6
# SpecificUseDetail2                14
# totBuildingDataLines               6
# YearBuilt                        131
# EffectiveYearBuilt               124
# SQFTmain                        3307
# Bedrooms                          66
# Bathrooms                         67
# Units                             63
# RecordingDate                   4877
# LandValue                       8062
# LandBaseYear                      46
# ImprovementValue                8490
# ImpBaseYear                       46
# TotalLandImpValue               9194
# HomeownersExemption                7
# RealEstateExemption               22
# FixtureValue                       2
# FixtureExemption                   2
# PersonalPropertyValue            178
# PersonalPropertyExemption          4
# isTaxableParcel?                   2
# TotalValue                      9213
# TotalExemption                    28
# netTaxableValue                 9447
# SpecialParcelClassification        1
# AdministrativeRegion              15
# Cluster                          287
# ParcelBoundaryDescription      10000
# HouseNo                         6442
# HouseFraction                      2
# StreetDirection                    4
# StreetName                      3489
# UnitNo                           760
# City                               1
# ZIPcode5                         119
# rowID                          10000
# CENTER_LAT                      9516
# CENTER_LON                      9515
# Location 1                      9516
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(30,20)) 
sns.heatmap(df.isnull(), cbar=False,annot_kws={'size': 100})
# Out:
# <AxesSubplot:>

# %%
df['TaxRateArea_CITY'].value_counts()
# Out:
# LOS ANGELES        9405
# unincorporated      592
# HUNTINGTON PARK       1
# CULVER CITY           1
# BEVERLY HILLS         1
# Name: TaxRateArea_CITY, dtype: int64

# %%
df['PropertyType'].value_counts()
# Out:
# SFR    6751
# R-I    1689
# CND    1505
# VAC      52
# OTH       3
# Name: PropertyType, dtype: int64

# %%
df['totBuildingDataLines'].value_counts()
# Out:
# 1    9215
# 2     629
# 0      69
# 3      66
# 4      15
# 5       6
# Name: totBuildingDataLines, dtype: int64

# %%
df['HouseFraction'].value_counts()
# Out:
# 1/2    21
# 1/4     3
# Name: HouseFraction, dtype: int64

# %%
fig=plt.figure()

ax = fig.add_subplot(1,1,1)
ax.hist(df['Bedrooms'],bins = 500)

plt.title('Distribution')
plt.xlabel('Rooms')
plt.ylabel('Number')
plt.xlim(0,30)
plt.show()

# %%
fig=plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.scatter(df['Bedrooms'],df['Bathrooms'])
plt.xlabel('Bedrooms')
plt.ylabel('Bathrooms')
plt.xlim(0,50)
plt.ylim(0,50)

fig=plt.figure()
ax2 = fig.add_subplot(1,1,1)
ax2.scatter(df['Bedrooms'],df['SQFTmain'])
plt.xlabel('Bedrooms')
plt.ylabel('SQFT main')
plt.xlim(0,50)
plt.ylim(0,100000)

fig=plt.figure()
ax3 = fig.add_subplot(1,1,1)
ax3.scatter(df['Bathrooms'],df['SQFTmain'])
plt.xlabel('Bathrooms')
plt.ylabel('SQFT main')
plt.xlim(0,50)
plt.ylim(0,100000)

# ax4 = fig.add_subplot(1,1,1)
# ax4.scatter(df['HouseFraction'],df['SQFTmain'])
# plt.xlabel('House Fraction')
# plt.ylabel('SQFT main')
# plt.xlim(0,50)
# plt.ylim(0,50)

plt.show()

# %%
corrMatrix = df.corr()
fig, ax = plt.subplots(figsize=(30,20))
sns.heatmap(corrMatrix,cbar=True, annot=True)
plt.show()

# %%
##Feature Engineering

# %%
df_fe = df.drop(['LandValue','LandBaseYear','ImprovementValue','ImpBaseYear','TotalLandImpValue','HomeownersExemption','RealEstateExemption','FixtureValue','FixtureExemption','PersonalPropertyValue','PersonalPropertyExemption','TotalExemption','netTaxableValue','RollYear','GeneralUseType','City'],axis=1)

# %%
df_fe.head()
# Out:
#       ZIPcode TaxRateArea_CITY         AIN  TaxRateArea    AssessorID  \
# 0  90037-3908      LOS ANGELES  5002017003          212  5002-017-003
# 1  90008-1725      LOS ANGELES  5045009008           67  5045-009-008
# 2  91356-1624      LOS ANGELES  2157002098           16  2157-002-098
# 3  90027-4725      LOS ANGELES  5430007005           13  5430-007-005
# 4  90063-3433   unincorporated  5234006014          932  5234-006-014
#
#                                   PropertyLocation PropertyType  \
# 0            1150 W 57TH ST  LOS ANGELES CA  90037          R-I
# 1        3939 WELLINGTON RD  LOS ANGELES CA  90008          SFR
# 2  18333 HATTERAS ST, NO 98  LOS ANGELES CA  91356          CND
# 3          3941 CLAYTON AVE  LOS ANGELES CA  90027          SFR
# 4         4250 MICHIGAN AVE  LOS ANGELES CA  90063          SFR
#
#   PropertyUseCode                SpecificUseType SpecificUseDetail1  ...  \
# 0            0400  Four Units  (Any Combination)  4 Stories or Less  ...
# 1            0101        Single Family Residence                NaN  ...
# 2            010C        Single Family Residence                NaN  ...
# 3            0100        Single Family Residence                NaN  ...
# 4            0100        Single Family Residence                NaN  ...
#
#   HouseNo  HouseFraction  StreetDirection     StreetName  UnitNo  ZIPcode5  \
# 0    1150            NaN                W        57TH ST     NaN   90037.0
# 1    3939            NaN              NaN  WELLINGTON RD     NaN   90008.0
# 2   18333            NaN              NaN    HATTERAS ST   NO 98   91356.0
# 3    3941            NaN              NaN    CLAYTON AVE     NaN   90027.0
# 4    4250            NaN              NaN   MICHIGAN AVE     NaN   90063.0
#
#             rowID  CENTER_LAT  CENTER_LON                    Location 1
# 0  20195002017003   33.990265 -118.295401  (33.99026509, -118.29540135)
# 1  20195045009008   34.014630 -118.339826   (34.01462956, -118.3398262)
# 2  20192157002098   34.178167 -118.531645  (34.17816673, -118.53164496)
# 3  20195430007005   34.100852 -118.277677  (34.10085245, -118.27767676)
# 4  20195234006014   34.038443 -118.173973  (34.03844261, -118.17397312)
#
# [5 rows x 35 columns]

# %%
df_fe.Bedrooms.quantile(0.99)
# Out:
# 21.0

# %%
df_fe[df_fe.Bedrooms<1].describe()
# Out:
#                 AIN   TaxRateArea  totBuildingDataLines    YearBuilt  \
# count  1.970000e+02    197.000000            197.000000   197.000000
# mean   5.002381e+09   2708.675127              0.690355  1185.908629
# std    1.018059e+09   5168.900259              0.589499   952.718003
# min    2.039022e+09      4.000000              0.000000     0.000000
# 25%    5.002004e+09     16.000000              0.000000     0.000000
# 50%    5.149006e+09     67.000000              1.000000  1920.000000
# 75%    5.479003e+09    964.000000              1.000000  1951.000000
# max    7.467002e+09  15117.000000              4.000000  2009.000000
#
#        EffectiveYearBuilt       SQFTmain  Bedrooms   Bathrooms       Units  \
# count          197.000000     197.000000     197.0  197.000000  197.000000
# mean          1236.345178    3094.898477       0.0    1.329949    3.329949
# std            951.372125   14411.711822       0.0    4.313927   11.741596
# min              0.000000       0.000000       0.0    0.000000    0.000000
# 25%              0.000000       0.000000       0.0    0.000000    0.000000
# 50%           1927.000000     630.000000       0.0    0.000000    0.000000
# 75%           1979.000000    1310.000000       0.0    1.000000    1.000000
# max           2011.000000  161173.000000       0.0   36.000000  118.000000
#
#        RecordingDate    TotalValue  AdministrativeRegion       Cluster  \
# count   1.970000e+02  1.970000e+02            197.000000    197.000000
# mean    2.008698e+07  1.060936e+06              9.598985   9845.441624
# std     9.726099e+04  4.414948e+06              5.800827   5700.442793
# min     1.971081e+07  0.000000e+00              2.000000   2114.000000
# 25%     2.004112e+07  9.546300e+04              7.000000   7187.000000
# 50%     2.013013e+07  2.585690e+05              9.000000   9296.000000
# 75%     2.016022e+07  5.455320e+05              9.000000   9591.000000
# max     2.018112e+07  4.926087e+07             30.000000  27636.000000
#
#             HouseNo      ZIPcode5         rowID  CENTER_LAT  CENTER_LON
# count    197.000000    196.000000  1.970000e+02  197.000000  197.000000
# mean    3277.050761  90182.030612  2.019500e+13   34.052083 -118.309847
# std     4056.637966    393.427841  1.018059e+09    0.089286    0.088253
# min        0.000000  90001.000000  2.019204e+13   33.714006 -118.620198
# 25%      645.000000  90014.750000  2.019500e+13   34.041202 -118.370355
# 50%     1540.000000  90032.000000  2.019515e+13   34.051012 -118.283002
# 75%     4764.000000  90064.250000  2.019548e+13   34.094458 -118.245027
# max    22633.000000  91607.000000  2.019747e+13   34.301043 -118.161096

# %%
df_fe.Bathrooms.quantile(0.99)
# Out:
# 23.0

# %%
df_fe[df_fe.Bathrooms<1].describe()
# Out:
#                 AIN   TaxRateArea  totBuildingDataLines    YearBuilt  \
# count  1.200000e+02    120.000000            120.000000   120.000000
# mean   4.867683e+09   1087.183333              0.458333   728.983333
# std    1.041575e+09   3136.868735              0.606628   945.236692
# min    2.039022e+09      4.000000              0.000000     0.000000
# 25%    4.325024e+09     13.000000              0.000000     0.000000
# 50%    5.161511e+09     67.000000              0.000000     0.000000
# 75%    5.517013e+09    200.000000              1.000000  1924.000000
# max    7.467002e+09  15117.000000              4.000000  2009.000000
#
#        EffectiveYearBuilt       SQFTmain    Bedrooms  Bathrooms       Units  \
# count          120.000000     120.000000  120.000000      120.0  120.000000
# mean           779.508333    3672.100000    0.033333        0.0    3.566667
# std            958.865480   18076.284663    0.257112        0.0   14.125329
# min              0.000000       0.000000    0.000000        0.0    0.000000
# 25%              0.000000       0.000000    0.000000        0.0    0.000000
# 50%              0.000000       0.000000    0.000000        0.0    0.000000
# 75%           1932.250000    1422.000000    0.000000        0.0    1.000000
# max           2009.000000  161173.000000    2.000000        0.0  118.000000
#
#        RecordingDate    TotalValue  AdministrativeRegion       Cluster  \
# count   1.200000e+02  1.200000e+02            120.000000    120.000000
# mean    2.007760e+07  1.432734e+06              8.983333   9118.100000
# std     1.077688e+05  5.608756e+06              5.861114   5647.193704
# min     1.971081e+07  0.000000e+00              2.000000   2114.000000
# 25%     2.003090e+07  4.466250e+04              4.000000   4365.500000
# 50%     2.012571e+07  2.227515e+05              9.000000   9157.500000
# 75%     2.015105e+07  7.341182e+05              9.000000   9438.000000
# max     2.018112e+07  4.926087e+07             30.000000  27636.000000
#
#             HouseNo      ZIPcode5         rowID  CENTER_LAT  CENTER_LON
# count    120.000000    119.000000  1.200000e+02  120.000000  120.000000
# mean    4014.708333  90208.521008  2.019487e+13   34.063439 -118.324286
# std     4054.629396    433.229748  1.041575e+09    0.080444    0.094322
# min        0.000000  90001.000000  2.019204e+13   33.714006 -118.620198
# 25%     1262.000000  90026.000000  2.019433e+13   34.033817 -118.384408
# 50%     2436.000000  90042.000000  2.019516e+13   34.062209 -118.317244
# 75%     5541.000000  90065.000000  2.019552e+13   34.102900 -118.253259
# max    22633.000000  91607.000000  2.019747e+13   34.301043 -118.161096

# %%
df_fe = df_fe[(df_fe.Bedrooms<df_fe.Bedrooms.quantile(0.99)) & (df_fe.Bedrooms>0)]

# %%
df_fe = df_fe[(df_fe.Bathrooms<df_fe.Bathrooms.quantile(0.99)) & (df_fe.Bathrooms>0)]

# %%
df_fe.shape
# Out:
# (9586, 35)

# %%
fig=plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.scatter(df_fe['Bedrooms'],df_fe['Bathrooms'])
plt.xlabel('Bedrooms')
plt.ylabel('Bathrooms')
plt.xlim(0,25)
plt.ylim(0,25)

plt.show()

# %%
df_fe['sqft/bedroom'] = df_fe['SQFTmain']/df_fe['Bedrooms']
df_fe['sqft/bathroom'] = df_fe['SQFTmain']/df_fe['Bathrooms']

# %%
df_fe.describe()
# Out:
#                 AIN   TaxRateArea  totBuildingDataLines    YearBuilt  \
# count  9.586000e+03   9586.000000           9586.000000  9586.000000
# mean   4.071938e+09    614.926560              1.082203  1949.406113
# std    1.590340e+09   2108.916846              0.315356    78.825317
# min    2.004002e+09      4.000000              1.000000     0.000000
# 25%    2.424002e+09     13.000000              1.000000  1931.000000
# 50%    4.264010e+09     16.000000              1.000000  1952.000000
# 75%    5.422002e+09     67.000000              1.000000  1967.000000
# max    7.563036e+09  15938.000000              5.000000  2019.000000
#
#        EffectiveYearBuilt      SQFTmain     Bedrooms    Bathrooms  \
# count         9586.000000   9586.000000  9586.000000  9586.000000
# mean          1954.499896   1912.115898     3.364073     2.455977
# std             96.745778   1246.216484     1.680270     1.423696
# min              0.000000    400.000000     1.000000     1.000000
# 25%           1944.000000   1212.000000     2.000000     2.000000
# 50%           1958.000000   1586.000000     3.000000     2.000000
# 75%           1975.000000   2220.000000     4.000000     3.000000
# max           2019.000000  53247.000000    19.000000    11.000000
#
#              Units  RecordingDate    TotalValue  AdministrativeRegion  \
# count  9586.000000   9.586000e+03  9.586000e+03           9586.000000
# mean      1.338827   2.008456e+07  5.404599e+05              6.140413
# std       1.230608   9.499314e+04  7.710134e+05              3.962540
# min       0.000000   1.948043e+07  0.000000e+00              2.000000
# 25%       1.000000   2.004041e+07  2.078800e+05              3.000000
# 50%       1.000000   2.011112e+07  3.715685e+05              4.000000
# 75%       1.000000   2.016022e+07  6.250015e+05              9.000000
# max      54.000000   2.018123e+07  3.633071e+07             28.000000
#
#             Cluster       HouseNo      ZIPcode5         rowID   CENTER_LAT  \
# count   9586.000000   9586.000000   9586.000000  9.586000e+03  9586.000000
# mean    6378.690382   7021.575422  90634.697163  2.019407e+13    34.097446
# std     3988.838167   6103.432685    644.958617  1.590340e+09     0.124162
# min     2102.000000      1.000000  90001.000000  2.019200e+13    33.708126
# 25%     3126.000000   1718.250000  90037.000000  2.019242e+13    34.016665
# 50%     4424.000000   5321.000000  90230.000000  2.019426e+13    34.098908
# 75%     9178.000000  10768.250000  91335.000000  2.019542e+13    34.197802
# max    28405.000000  28006.000000  91607.000000  2.019756e+13    34.329560
#
#         CENTER_LON  sqft/bedroom  sqft/bathroom
# count  9586.000000   9586.000000    9586.000000
# mean   -118.388257    581.037080     818.972379
# std       0.119099    214.848785     266.803926
# min    -118.667832    182.000000     251.857143
# 25%    -118.467923    434.666667     640.000000
# 50%    -118.385504    537.000000     776.500000
# 75%    -118.295153    672.000000     945.500000
# max    -118.127673   5324.700000    4840.636364

# %%
df_fe['sqft/bedroom'].quantile(0.99)
# Out:
# 1321.2499999999993

# %%
df_fe['sqft/bathroom'].quantile(0.99)
# Out:
# 1647.0249999999987

# %%
df_fe = df_fe[(df_fe['sqft/bedroom']<df_fe['sqft/bedroom'].quantile(0.99)) & (df_fe['sqft/bathroom']<df_fe['sqft/bathroom'].quantile(0.99))]

# %%
df_fe.shape
# Out:
# (9407, 37)

# %%
fig=plt.figure()

fig=plt.figure()
ax2 = fig.add_subplot(1,1,1)
ax2.scatter(df_fe['Bedrooms'],df_fe['SQFTmain'])
plt.xlabel('Bedrooms')
plt.ylabel('SQFT main')
plt.xlim(0,25)
plt.ylim(0,20000)

fig=plt.figure()
ax3 = fig.add_subplot(1,1,1)
ax3.scatter(df_fe['Bathrooms'],df_fe['SQFTmain'])
plt.xlabel('Bathrooms')
plt.ylabel('SQFT main')
plt.xlim(0,15)
plt.ylim(0,20000)

plt.show()

# %%
df_fe.columns
# Out:
# Index(['ZIPcode', 'TaxRateArea_CITY', 'AIN', 'TaxRateArea', 'AssessorID',
#        'PropertyLocation', 'PropertyType', 'PropertyUseCode',
#        'SpecificUseType', 'SpecificUseDetail1', 'SpecificUseDetail2',
#        'totBuildingDataLines', 'YearBuilt', 'EffectiveYearBuilt', 'SQFTmain',
#        'Bedrooms', 'Bathrooms', 'Units', 'RecordingDate', 'isTaxableParcel?',
#        'TotalValue', 'SpecialParcelClassification', 'AdministrativeRegion',
#        'Cluster', 'ParcelBoundaryDescription', 'HouseNo', 'HouseFraction',
#        'StreetDirection', 'StreetName', 'UnitNo', 'ZIPcode5', 'rowID',
#        'CENTER_LAT', 'CENTER_LON', 'Location 1', 'sqft/bedroom',
#        'sqft/bathroom'],
#       dtype='object')

# %%
df_fe.shape
# Out:
# (9407, 37)

# %%
df_fe.isnull().sum()
# Out:
# ZIPcode                           0
# TaxRateArea_CITY                  0
# AIN                               0
# TaxRateArea                       0
# AssessorID                        0
# PropertyLocation                  0
# PropertyType                      0
# PropertyUseCode                   0
# SpecificUseType                   0
# SpecificUseDetail1             7877
# SpecificUseDetail2             6413
# totBuildingDataLines              0
# YearBuilt                         0
# EffectiveYearBuilt                0
# SQFTmain                          0
# Bedrooms                          0
# Bathrooms                         0
# Units                             0
# RecordingDate                     0
# isTaxableParcel?                  0
# TotalValue                        0
# SpecialParcelClassification    9373
# AdministrativeRegion              0
# Cluster                           0
# ParcelBoundaryDescription         0
# HouseNo                           0
# HouseFraction                  9383
# StreetDirection                6997
# StreetName                        0
# UnitNo                         8062
# ZIPcode5                          0
# rowID                             0
# CENTER_LAT                        0
# CENTER_LON                        0
# Location 1                        0
# sqft/bedroom                      0
# sqft/bathroom                     0
# dtype: int64

# %%
df_fe['SpecialParcelClassification'].value_counts()
# Out:
# Public (non-taxable government-owned)    34
# Name: SpecialParcelClassification, dtype: int64
